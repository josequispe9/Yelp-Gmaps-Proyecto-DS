# %%
import pandas as pd

# Lee solo las primeras 20,000 filas del archivo JSON por cuestiones de rendimiento
df = pd.read_json('D:\\HENRY REPO\\Proyecto Final\\GOOGLE MAPS\\Metadata Sitios\\metadata-sitios-20250113T193130Z-001\\metadata-sitios\\9.json', lines=True, nrows=200000)

df.head()
# Out:
#                                               name  \
# 0                                  Porter Pharmacy
# 1  MemorialCare Breast Center - Irvine Sand Canyon
# 2                       U-Haul Neighborhood Dealer
# 3                              Nick's Auto Service
# 4                               Alton Self Storage
#
#                                              address  \
# 0  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1  MemorialCare Breast Center - Irvine Sand Canyo...
# 2  U-Haul Neighborhood Dealer, 1690 E 112th Ave, ...
# 3  Nick's Auto Service, 16291 Construction Cir E ...
# 4  Alton Self Storage, 2215 Alton Pkwy, Irvine, C...
#
#                                  gmap_id description   latitude   longitude  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8        None  32.388300  -83.357100
# 1  0x80dcdd3b95c7284b:0x23d9b4440c982d37        None  33.668389 -117.765649
# 2  0x876c769e600eda1d:0xdf1fffc2e00e1fe1        None  39.899189 -104.966765
# 3  0x80dcdc81a6d04bd3:0x72d18ce084849c10        None  33.694544 -117.821692
# 4  0x80dcde9ed485d8bb:0xadfae03de02d931d        None  33.692216 -117.837010
#
#                                             category  avg_rating  \
# 0                                         [Pharmacy]         4.9
# 1                              [Mammography service]         4.7
# 2  [Truck rental agency, Trailer rental service, ...         3.9
# 3  [Auto repair shop, Brake shop, Car inspection ...         4.3
# 4                            [Self-storage facility]         4.3
#
#    num_of_reviews price                                              hours  \
# 0              16  None  [[Friday, 8AM–6PM], [Saturday, 8AM–12PM], [Sun...
# 1              33  None  [[Tuesday, 8:30AM–5PM], [Wednesday, 8:30AM–5PM...
# 2              18     $                                               None
# 3              78  None  [[Tuesday, 6AM–6PM], [Wednesday, 6AM–6PM], [Th...
# 4             118  None  [[Tuesday, 9AM–6PM], [Wednesday, 9AM–6PM], [Th...
#
#                                                 MISC                  state  \
# 0  {'Service options': ['In-store shopping', 'Sam...      Open ⋅ Closes 6PM
# 1  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 8:30AM
# 2                                               None                   None
# 3  {'Accessibility': ['Wheelchair accessible entr...      Open ⋅ Closes 6PM
# 4  {'Accessibility': ['Wheelchair accessible entr...     Closed ⋅ Opens 9AM
#
#                                     relative_results  \
# 0  [0x88f16e41929435cf:0x5b2532a2885e9ef6, 0x88f1...
# 1  [0x80dcdc4aad8cb91f:0x62bdeb79a44d7633, 0x80dc...
# 2  [0x876c75d05d0e1bf3:0x1d2d9897d0dec9cb, 0x876c...
# 3  [0x80dcdc23021a683d:0x51385c359da6b12e, 0x80dc...
# 4  [0x80dcde8138ba81e5:0xb6d8b753a1b76050, 0x80dc...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...

# %%
# Tamaño de Dataset

df.shape
# Out:
# (200000, 15)

# %%
# Observacion de los tipos de datos del dataset y mas informacion

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name              199999 non-null  object
#  1   address           195898 non-null  object
#  2   gmap_id           200000 non-null  object
#  3   description       19966 non-null   object
#  4   latitude          200000 non-null  float64
#  5   longitude         200000 non-null  float64
#  6   category          199051 non-null  object
#  7   avg_rating        200000 non-null  float64
#  8   num_of_reviews    200000 non-null  int64
#  9   price             22261 non-null   object
#  10  hours             152915 non-null  object
#  11  MISC              160941 non-null  object
#  12  state             155024 non-null  object
#  13  relative_results  184939 non-null  object
#  14  url               200000 non-null  object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 22.9+ MB

# %%
df.dtypes


# las columnas estan bien representadas en el formato de contenido
# Out:
# name                 object
# address              object
# gmap_id              object
# description          object
# latitude            float64
# longitude           float64
# category             object
# avg_rating          float64
# num_of_reviews        int64
# price                object
# hours                object
# MISC                 object
# state                object
# relative_results     object
# url                  object
# dtype: object

# %%
# Obsevamos las columnas del dataset

df.columns
# Out:
# Index(['name', 'address', 'gmap_id', 'description', 'latitude', 'longitude',
#        'category', 'avg_rating', 'num_of_reviews', 'price', 'hours', 'MISC',
#        'state', 'relative_results', 'url'],
#       dtype='object')

# %%
# OBERVAMOS VALORES UNICOS

print('\nvalores unicos avg_rating: ', df.avg_rating.unique())
print('\nvalores unicos num_of_reviews: ', df.num_of_reviews.unique())
print('\nvalores unicos price: ', df.price.unique())
# Out:
# valores unicos avg_rating:  [4.9 4.7 3.9 4.3 4.4 3.4 3.8 4.6 4.  5.  4.2 4.8 2.8 4.5 3.3 2.5 3.  1.
#  4.1 3.5 2.7 3.1 1.4 3.6 3.7 2.6 2.4 3.2 2.9 2.  2.3 1.5 1.9 2.2 2.1 1.2
#  1.3 1.6 1.8 1.7 1.1]
#
# valores unicos num_of_reviews:  [  16   33   18   78  118   12  388    8   35   27   38    1   24    7
#    55   14    3    2   13  102   48   68   98    6   28  527    4  278
#   128  176   19   57   88   15   97   36   46   17   25  178  177   45
#   855  198   26  124   54   65    5   66   95   34  168  135   58  188
#   146  140   79  106   43   56  108   87   86  331  215   84  147   67
#    75  117   64   53   44   37  238  104   41  137  126  298  122  436
#   148   85   73   20  113   74   40   47  105  157   62   93  288  134
#   116  205  112  218  103  156   82   29   76    9  272   60   61  206
#    31  127  138  216   96   22  158  264  131  145  114  214   42  303
#    83  255  133  958   90  166  186   91  227   94  378   77  235   23
#   125  286   30  234   32  265  328  173  233 1038   92  143  136  308
#   194  208  346   11  465  618  306  163  179  845  174  192   39  183
#   107  142  154  988  316  193  119  164  343  338  408  366  323  248
#   171  458   52  417  268   21  246   63   72  503   10  155  420  196
#   144  258  153  228  368   99  275  335  358  438  418  217  506  115
#   367  236  247  162   50  244  256  111  454  348  414  165  354  190
#   448  561  110  100  728  263  326  220  285  175  167  266   49  953
#   594  467  213  273  533  376  212  324   71  488  185  123  673  237
#   468  187  498  405  276   51  197  245   69  109  311  854  280  985
#   261  207  152  184  444  477  333  254  648  211   70   80  494 2088
#    89  416  305  427  120  387  463  341  195  342  698  568  223  665
#   257  222  182 1035  189  363  294  600  678  224  191  805 1353  429
#   262  209  229  295  625  928  243   59  546  428  758  787  518  396
#   302  588  525  170  318  230  668 1158  129  101 1375  537  314  149
#   607  203  160  534  355  798  344  225  353  638  383  242  287  296
#   828   81  415  510  574  259  357  279  325  345  267  478  745  337
#   282 1658  151  407  479  121  283  457  172  307  231  226  382  914
#   180 1076  202  299  132  313  336  553  292  253  403  863  440  398
#   685  395  608  204  538  327  840 2006  554  455  434 1206  437  575
#   708  377  604  364  169  707 1380  772  161  692  968  139  356  453
#   347  241  812  291  713 1178  456  284  293  475 1598  548  558  424
#  2724  628  446 1718  508  464  887  547  587  634  352  492  545  528
#   394  393  423  485  277  747  426  535  130  373 1563 1103  898  532
#   392  667  577  384  832 1238  526 1195  397 1097  647 1123  724  425
#   399  838  565  938  786  598 1098  512  517  804  372  681  505  462
#  1018  495  586  690  926  249  515  592  785 1285  274  473  878 1017
#   322  523  998  304  516  150  738  386  317 1203  375  603  651 1265
#   493 1448  806  433  232  683  297  560  365 2458  269  626  329  451
#   497  315  688  581  582  432  736  332  200  792  704  519  141  715
#   627  727  290  159  636  808  181  319  658  654  710  385  911  814
#   676 1618  788  818 1128  507  447  675 1008  351  567  593 1293  585
#   252  404  964  334  362  576  443  709  251 2219  659  766 1568  837
#   461  924  380  936  401  445  552  312  748 1968  666  289  502 1464
#  1470  514  578  504  219  410  632  718  824  374  765  530  400 1778
#   597  616  823  301  572  879  697  613  768 1798 1674  637  452  435
#  1105  536 1034  381  978  260  486 1058 1445  390  201 2871  655 1218
#   421  705  524  450  743  442 1125  663  605  406  371  469  774  858
#  1025  556  764  633  619  239  624  555 1339  630 1047  513  339  476
#   657 1075  852 1528 1006  844  449  370 1254  221  340  540  874  531
#  2130  412 1065  888  623  483  330  199 1045 1084 1067 1315  696  614
#   496  460  868  466  599  595  908  703  270  686  482  557  484  740
#  1497  847  781  422 1392 1609  848  606 1237 1996  881  240 1064  810
#   693  996  542  402  948  867 1458  563 1607  672 1348  609  320  615
#   360 1267 1298  584  642  474  580  695 3397 2580  413  875  309 2454
#  2588  617 1028  646 1248  635  559  521 1004  776  790  961  350 1358
#   694  522 1328 1584 1478 1376  866  649  843  570  752 3217 2128  754
#  1092 1204  391 1198  755  767  700  250  349  359  674  321 1243  271
#   726  753 1228  653  782 1938  652 2575  491  923 2238  809  778]
#
# valores unicos price:  [None '$' '$$' '$$$' '$$$$']

# %% [markdown]
# ## Visualización general
#
# heatmap de correlación (Mapa de correlaciones)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))
sns.heatmap(df.fillna('NAN').corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f", vmin=-1, vmax=1)
plt.title("Matriz de correlación")
plt.show()

# %% [markdown]
# No se puede observar alguna relacion entre las columnas

# %% [markdown]
# ## Valores faltantes (Missing values)

# %%
# Verificamos si existen valores nulos

df.isnull().sum()
# Out:
# name                     1
# address               4102
# gmap_id                  0
# description         180034
# latitude                 0
# longitude                0
# category               949
# avg_rating               0
# num_of_reviews           0
# price               177739
# hours                47085
# MISC                 39059
# state                44976
# relative_results     15061
# url                      0
# dtype: int64

# %%
#porcentaje de nulos

df.isnull().mean() * 100
# Out:
# name                 0.0005
# address              2.0510
# gmap_id              0.0000
# description         90.0170
# latitude             0.0000
# longitude            0.0000
# category             0.4745
# avg_rating           0.0000
# num_of_reviews       0.0000
# price               88.8695
# hours               23.5425
# MISC                19.5295
# state               22.4880
# relative_results     7.5305
# url                  0.0000
# dtype: float64

# %%
# !pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.5.2)
# Requirement already satisfied: numpy in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from missingno) (1.24.1)
# Requirement already satisfied: matplotlib in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from missingno) (3.6.3)
# Requirement already satisfied: scipy in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from missingno) (1.10.0)
# Requirement already satisfied: seaborn in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from missingno) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from seaborn->missingno) (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=0.25->seaborn->missingno) (2022.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: C:\Users\jhnnc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import missingno as msno
import pandas as pd

# Ver el gráfico de valores faltantes por columna
msno.bar(df, figsize=(12,8))

# Ver el mapa de calor de correlaciones entre valores nulos
msno.heatmap(df, figsize=(12,8))
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Duplicados

# %%
df.iloc[:, [0,1,2,3,4,5,7,8,9,12]].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Distribución y valores atípicos (outliers)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

columnas = ['latitude', 'longitude', 'avg_rating', 'num_of_reviews']

# Convertimos el DataFrame a formato largo (long-form)
df_long = df[columnas].melt(var_name='Variable', value_name='Valor')

# Creamos una figura con 2x2 subplots
fig, axs = plt.subplots(1, 4, figsize=(12, 5))  # 2 filas, 2 columnas
axs = axs.flatten()  # aplanamos para acceder más fácil

# Para cada variable, hacemos un boxplot en un subplot
for i, variable in enumerate(columnas):

    sns.boxplot(y=df[variable], ax=axs[i], )
    axs[i].set_title(f'Boxplot de {variable}')

# Ajustamos espacios
plt.tight_layout()
plt.show()
