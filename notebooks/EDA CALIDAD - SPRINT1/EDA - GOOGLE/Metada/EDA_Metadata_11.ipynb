# %%
import pandas as pd

# Lee solo las primeras 20,000 filas del archivo JSON por cuestiones de rendimiento
df = pd.read_json('D:\\HENRY REPO\\Proyecto Final\\GOOGLE MAPS\\Metadata Sitios\\metadata-sitios-20250113T193130Z-001\\metadata-sitios\\11.json', lines=True, nrows=200000)

df.head()
# Out:
#                                  name  \
# 0                     Porter Pharmacy
# 1                      Mcguinns store
# 2               Gentle Hands Grooming
# 3  Smokecignals Electronic Cigarettes
# 4     Advanced Home Medical Equipment
#
#                                              address  \
# 0  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1   Mcguinns store, 4884 NC-9, Mill Spring, NC 28756
# 2  Gentle Hands Grooming, 156 US-176, Saluda, NC ...
# 3  Smokecignals Electronic Cigarettes, 2108 W Tho...
# 4  Advanced Home Medical Equipment, 885 Franklin ...
#
#                                  gmap_id description   latitude  longitude  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8        None  32.388300 -83.357100
# 1  0x88575f0654bd7c03:0xca3e467f7e766ad5        None  35.359437 -82.179693
# 2  0x8859db7fe56d01c7:0xf90f3bdb3c62ba47        None  35.236050 -82.351049
# 3  0x862722f489700e87:0x62c847c188bd5aa9        None  30.501326 -90.484117
# 4  0x88523ca20145acc7:0x4b61a60bdc7d641e        None  33.931450 -84.495418
#
#                  category  avg_rating  num_of_reviews price  \
# 0              [Pharmacy]         4.9              16  None
# 1    [General store, ATM]         5.0               4  None
# 2           [Pet groomer]         4.9               8  None
# 3       [Vaporizer store]         4.4              57  None
# 4  [Medical supply store]         4.8             228  None
#
#                                                hours  \
# 0  [[Friday, 8AM–6PM], [Saturday, 8AM–12PM], [Sun...
# 1  [[Wednesday, 6AM–6PM], [Thursday, 6AM–8PM], [F...
# 2  [[Wednesday, 9:30AM–4:30PM], [Thursday, 9AM–4:...
# 3                                               None
# 4  [[Wednesday, 9AM–12PM], [Thursday, 9AM–12PM], ...
#
#                                                 MISC                   state  \
# 0  {'Service options': ['In-store shopping', 'Sam...       Open ⋅ Closes 6PM
# 1  {'Service options': ['In-store shopping', 'Del...  Closed ⋅ Opens 6AM Thu
# 2                                               None  Closed ⋅ Opens 9AM Thu
# 3                                               None                    None
# 4  {'Accessibility': ['Wheelchair accessible entr...  Closed ⋅ Opens 9AM Thu
#
#                                     relative_results  \
# 0  [0x88f16e41929435cf:0x5b2532a2885e9ef6, 0x88f1...
# 1  [0x88575f0654bd7c03:0x1e5bcb4ee2d6072, 0x88575...
# 2  [0x8859db7e2299101f:0xf71932e69cc2ba14, 0x8857...
# 3  [0x862722eb9415f87d:0xb2b9b86ad30ca06a, 0x8627...
# 4  [0x88f515da59770615:0x3d0ce33a674eded2, 0x88f5...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...

# %%
# Tamaño de Dataset

df.shape
# Out:
# (200000, 15)

# %%
# Observacion de los tipos de datos del dataset y mas informacion

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name              199999 non-null  object
#  1   address           196473 non-null  object
#  2   gmap_id           200000 non-null  object
#  3   description       26468 non-null   object
#  4   latitude          200000 non-null  float64
#  5   longitude         200000 non-null  float64
#  6   category          199273 non-null  object
#  7   avg_rating        200000 non-null  float64
#  8   num_of_reviews    200000 non-null  int64
#  9   price             30257 non-null   object
#  10  hours             158309 non-null  object
#  11  MISC              167302 non-null  object
#  12  state             161686 non-null  object
#  13  relative_results  186697 non-null  object
#  14  url               200000 non-null  object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 22.9+ MB

# %%
df.dtypes


# las columnas estan bien representadas en el formato de contenido
# Out:
# name                 object
# address              object
# gmap_id              object
# description          object
# latitude            float64
# longitude           float64
# category             object
# avg_rating          float64
# num_of_reviews        int64
# price                object
# hours                object
# MISC                 object
# state                object
# relative_results     object
# url                  object
# dtype: object

# %%
# Obsevamos las columnas del dataset

df.columns
# Out:
# Index(['name', 'address', 'gmap_id', 'description', 'latitude', 'longitude',
#        'category', 'avg_rating', 'num_of_reviews', 'price', 'hours', 'MISC',
#        'state', 'relative_results', 'url'],
#       dtype='object')

# %%
# OBERVAMOS VALORES UNICOS

print('\nvalores unicos avg_rating: ', df.avg_rating.unique())
print('\nvalores unicos num_of_reviews: ', df.num_of_reviews.unique())
print('\nvalores unicos price: ', df.price.unique())
# Out:
# valores unicos avg_rating:  [4.9 5.  4.4 4.8 4.  4.6 3.4 4.5 4.3 4.2 4.7 3.6 3.2 3.5 3.8 3.9 3.1 1.8
#  3.  1.2 2.5 1.1 3.7 4.1 2.1 2.8 2.9 2.  2.6 2.4 1.  2.2 2.7 3.3 2.3 1.6
#  1.4 1.5 1.7 1.9 1.3]
#
# valores unicos num_of_reviews:  [  16    4    8   57  228   78   48    2  164   38  248    5   18   40
#    28    3    6   53   25   23    1   34  106   68  208   58  138   43
#    26    7  107  288   88   98   45   67   63  117   56   27   47   29
#    14   87   32  124   44  518   61  104  236  245  173   33   36  128
#   283  118   85  145  133  233  317  112  121  197  226   24  153  178
#    15   84   37  237   54  148   97   64   94   13  147  308  146  243
#   158   74  154  217  108  116  168   55  378  115   35   83  198  126
#   105  395  166  127   17  188   92   69   77   72  213  218  119  136
#   155  284  285  186   96   75  100  177  268   31  286   95   66  258
#    93   65   76  373  142  277   86   82   73  180  125  163   71   89
#   135  114  354  703  165  103  478   30  568  238  150  296  298  278
#   698  174  113   11   52  388  418   12  551   20  893  123  223   19
#   137  149  416  270   41  555  276  225  264  398  167  247  227  345
#   139  514  266   46   39    9  152  274  204  111  185   59  195  214
#   328  327  156  190  468   10  205   81  196  206  313  175  316   49
#   338   60  564  838  578  194  181  141  527  134  646  304  978  215
#   132   42  321  344  176  224  129  122  250 1448  193  157  358  310
#   508  257  144  255  337  234  436   70  405  318   99  101  161  262
#   282  131  324  558  184  210   91  203  244  202  606  332  192  455
#   628  171  306  408   22  435  191  294  216  207  366  375  693 1218
#   417  758  275  267 1694  143   90  187  516  368   62  201  528  385
#   348  428  548  102  263  874  246  269  183  293  159  249  260  120
#   503  474  287  466  339  695  505  297  668  242  343 1156  733  616
#   638  305  333  574  182   79  504  356  647  252   50  109  302   21
#   335 1578  458  531  538  336  498  357  377  413  456 1337  256  289
#   241  604  172   51  918  253  618  355  485  532 1538  212  448  598
#   353  523 1208  414  170  624  714  678  160  140  438 1244  664  323
#   362  291  371  886  254  823  396  235  747  334  272  712  326  465
#   415 1313  271  281  231  325  209  162  364 1355  976  386  868  467
#  1213  434 1141  352  452  656  151  211  384  858  110  588  342  995
#   232 1045  422  409  765  314  820  608  648  392 1368  222  605  295
#   346  908  475 1655  818   80  709  506  964  736  370 1848  526  738
#   406 1113  783  728  397  666 1088  221  265  273  426  495  517  424
#   778  404  315 1005  200  130 1952  387  402  320  382  938  376  179
#   312  611  473  488  777  479  347  780  581  425  794  737  966  383
#   786  169  462  546  502  189  453 1672  393  350  636 1385  828  896
#   251  534 1474  614  307  494  663 1118  391  463  447  437  381  707
#   427  699  985  513  363  635  407  367  607  871  537  372  825  403
#  1195 3981  593  457  788  483 1924  486  229  459  341 1202  793  400
#   725  433  586  451  553  576  351  688  988 3008  752 1119  644  808
#   708  219  454 1582  240  545  423  394  556 1248  878  583  444  745
#   998 1105  374  544  421  764  633 2297  658  577  303  361  554  541
#   848  602 1335  365 1317  888  497  511  575  806  445 1072 1855  968
#  1157  948  697  748 1077  587  290  230 1023  476  525  960  637  239
#   542  641  653  744 1056  798 2075  543  875  340  654  623  292  784
#   816  615  552 1221  547 1058  535 1098 1393  827  895  560  322 1178
#   955 1520 1476 1188 2338 1124  813 1174 1133  946  928  685 1014  533
#   220 1016  718  493 1182 1137  390  300  947 1878  491  557  565  655
#   550 1938 1037  472  470  652 1348  925 1015  442  487  596  905 1435
#  1148 1978 1154  837  691  903 1693  311  563  519  970  634  822  866
#   279 1063  773 1255  735 1026  972 1598  969 1046  360  846  482 2373
#  2193  329 1295  309 1407  443 1128 1027 1158 1175  843  926 2148  573
#   676  280  481  446  686  536 1258 1327  562  755  412  898  432 1338
#   705  681  727 1268  609  776 1293  740  359 1639  524 1168 1198  674
#   805 1054  199  484 1381  301  567  864  779  613  401 1738  815 1239
#  2048  996  522 1647 1493  754  331  496  429  441  594  814 1024 1479
#   702  411 2640  515  645 1692 1235  592 2318  768  877  785 1236  319
#   852  582 1042 1417 2294  579  957 1430  617  997  591 1256 1123 1238
#   597 1087  792 1628  684  584  885  799  512  897  717  833  904 1686
#   854  627 1095 1307  521 1270  831  724  661 1543  673 1418  756 1166
#   430  937  894  781  696  726  603  687  499 1018  379 1467  766 1747
#   625  461 1288 1136 1555  675  490  389  477  797 1114 2579 2105 1277
#   753 1568  734  906  492  464  984 1518  845  683 5115 1601  884 2886
#   865  775  883  751  507  967 1309  913 1563 1078 1074 2117 1108 1028
#   795 1142 1253 1298  715 2728  811 1086  572 1138 1897 2084  330 1444
#  2358  916 1055  930  907 5525 1504 1008 2258 2147  677  657 1928  509
#   824  704 1625 1888 1814 1011  632  595  857 1318  626 1115  945 1828
#  1358  774  887 1196  851 1383 2182  769 2887  835  796 1342  802 1147
#  1025 1241 1057  665  821  612 2788  642 1228  746 1404  950  890  958
#   600  721 1225 2046 2115]
#
# valores unicos price:  [None '$' '$$' '$$$' '$$$$']

# %% [markdown]
# ## Visualización general
#
# heatmap de correlación (Mapa de correlaciones)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))
sns.heatmap(df.fillna('NAN').corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f", vmin=-1, vmax=1)
plt.title("Matriz de correlación")
plt.show()

# %% [markdown]
# No se puede observar alguna relacion entre las columnas

# %% [markdown]
# ## Valores faltantes (Missing values)

# %%
# Verificamos si existen valores nulos

df.isnull().sum()
# Out:
# name                     1
# address               3527
# gmap_id                  0
# description         173532
# latitude                 0
# longitude                0
# category               727
# avg_rating               0
# num_of_reviews           0
# price               169743
# hours                41691
# MISC                 32698
# state                38314
# relative_results     13303
# url                      0
# dtype: int64

# %%
#porcentaje de nulos

df.isnull().mean() * 100
# Out:
# name                 0.0005
# address              1.7635
# gmap_id              0.0000
# description         86.7660
# latitude             0.0000
# longitude            0.0000
# category             0.3635
# avg_rating           0.0000
# num_of_reviews       0.0000
# price               84.8715
# hours               20.8455
# MISC                16.3490
# state               19.1570
# relative_results     6.6515
# url                  0.0000
# dtype: float64

# %%
# !pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.5.2)
# Requirement already satisfied: numpy in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from missingno) (1.24.1)
# Requirement already satisfied: matplotlib in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from missingno) (3.6.3)
# Requirement already satisfied: scipy in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from missingno) (1.10.0)
# Requirement already satisfied: seaborn in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from missingno) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from seaborn->missingno) (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=0.25->seaborn->missingno) (2022.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: C:\Users\jhnnc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import missingno as msno
import pandas as pd

# Ver el gráfico de valores faltantes por columna
msno.bar(df, figsize=(12,8))

# Ver el mapa de calor de correlaciones entre valores nulos
msno.heatmap(df, figsize=(12,8))
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Duplicados

# %%
df.iloc[:, [0,1,2,3,4,5,7,8,9,12]].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Distribución y valores atípicos (outliers)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

columnas = ['latitude', 'longitude', 'avg_rating', 'num_of_reviews']

# Convertimos el DataFrame a formato largo (long-form)
df_long = df[columnas].melt(var_name='Variable', value_name='Valor')

# Creamos una figura con 2x2 subplots
fig, axs = plt.subplots(1, 4, figsize=(12, 5))  # 2 filas, 2 columnas
axs = axs.flatten()  # aplanamos para acceder más fácil

# Para cada variable, hacemos un boxplot en un subplot
for i, variable in enumerate(columnas):

    sns.boxplot(y=df[variable], ax=axs[i], )
    axs[i].set_title(f'Boxplot de {variable}')

# Ajustamos espacios
plt.tight_layout()
plt.show()
