# %%
import pandas as pd

# Lee solo las primeras 20,000 filas del archivo JSON por cuestiones de rendimiento
df = pd.read_json('D:\\HENRY REPO\\Proyecto Final\\GOOGLE MAPS\\Metadata Sitios\\metadata-sitios-20250113T193130Z-001\\metadata-sitios\\4.json', lines=True, nrows=200000)

df.head()
# Out:
#                               name  \
# 0                  Porter Pharmacy
# 1         Pittsburgh Circus School
# 2                 Freedom ElecTech
# 3             Dietz Floral & Gifts
# 4  Beech Mountain Community Center
#
#                                              address  \
# 0  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1  Pittsburgh Circus School, 6800 Brighton Rd 2nd...
# 2  Freedom ElecTech, 521 NC-105 Extension #3, Boo...
# 3  Dietz Floral & Gifts, 549 Lincoln Ave, Bellevu...
# 4  Beech Mountain Community Center, 60 Flat Sprin...
#
#                                  gmap_id description   latitude  longitude  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8        None  32.388300 -83.357100
# 1  0x8834f5bb828394c3:0x8c8cd12a81fcc81a        None  40.505382 -80.078735
# 2  0x8850fa407ebe7c75:0x4e79ef72c51b2f64        None  36.210733 -81.666781
# 3  0x8834f503bec584f3:0x4dcab098bbb36236        None  40.496279 -80.057246
# 4  0x88508c6d4a58520f:0x8bea3f3791d009b5        None  36.237188 -81.930071
#
#                                             category  avg_rating  \
# 0                                         [Pharmacy]         4.9
# 1                        [Gymnastics center, Circus]         3.9
# 2  [Electrician, Audio visual consultant, Audio v...         4.5
# 3            [Florist, Gift basket store, Gift shop]         4.3
# 4                                       [Auditorium]         4.6
#
#    num_of_reviews price                                              hours  \
# 0              16  None  [[Friday, 8AM–6PM], [Saturday, 8AM–12PM], [Sun...
# 1              16  None  [[Saturday, 9AM–1PM], [Sunday, 6–9PM], [Monday...
# 2               8  None  [[Saturday, 10AM–2PM], [Sunday, Closed], [Mond...
# 3              38  None  [[Saturday, 9AM–4PM], [Sunday, Closed], [Monda...
# 4               5  None                                               None
#
#                                                 MISC                   state  \
# 0  {'Service options': ['In-store shopping', 'Sam...       Open ⋅ Closes 6PM
# 1  {'From the business': ['Identifies as women-le...  Closed ⋅ Opens 6PM Sun
# 2                                               None  Closed ⋅ Opens 8AM Mon
# 3  {'Service options': ['Same-day delivery'], 'Ac...      Permanently closed
# 4  {'Accessibility': ['Wheelchair accessible entr...                    None
#
#                                     relative_results  \
# 0  [0x88f16e41929435cf:0x5b2532a2885e9ef6, 0x88f1...
# 1                                               None
# 2  [0x8850fa308494fc8d:0x4f7268d52953ea5c, 0x8850...
# 3  [0x8834f3c5bb960cc3:0x8a96adaca50087f5, 0x8834...
# 4  [0x88508ce75fb3884b:0x820fd05a10d7602a, 0x8850...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...

# %%
# Tamaño de Dataset

df.shape
# Out:
# (200000, 15)

# %%
# Observacion de los tipos de datos del dataset y mas informacion

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name              199999 non-null  object
#  1   address           193773 non-null  object
#  2   gmap_id           200000 non-null  object
#  3   description       11769 non-null   object
#  4   latitude          200000 non-null  float64
#  5   longitude         200000 non-null  float64
#  6   category          198586 non-null  object
#  7   avg_rating        200000 non-null  float64
#  8   num_of_reviews    200000 non-null  int64
#  9   price             12321 non-null   object
#  10  hours             143154 non-null  object
#  11  MISC              148791 non-null  object
#  12  state             146488 non-null  object
#  13  relative_results  177523 non-null  object
#  14  url               200000 non-null  object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 22.9+ MB

# %%
df.dtypes


# las columnas estan bien representadas en el formato de contenido
# Out:
# name                 object
# address              object
# gmap_id              object
# description          object
# latitude            float64
# longitude           float64
# category             object
# avg_rating          float64
# num_of_reviews        int64
# price                object
# hours                object
# MISC                 object
# state                object
# relative_results     object
# url                  object
# dtype: object

# %%
# Obsevamos las columnas del dataset

df.columns
# Out:
# Index(['name', 'address', 'gmap_id', 'description', 'latitude', 'longitude',
#        'category', 'avg_rating', 'num_of_reviews', 'price', 'hours', 'MISC',
#        'state', 'relative_results', 'url'],
#       dtype='object')

# %%
# OBERVAMOS VALORES UNICOS

print('\nvalores unicos avg_rating: ', df.avg_rating.unique())
print('\nvalores unicos num_of_reviews: ', df.num_of_reviews.unique())
print('\nvalores unicos price: ', df.price.unique())
# Out:
# valores unicos avg_rating:  [4.9 3.9 4.5 4.3 4.6 5.  4.4 3.  4.8 4.2 4.  3.3 3.8 3.7 4.7 1.5 3.5 2.8
#  3.2 3.6 2.9 3.4 2.6 4.1 1.  2.4 2.3 2.1 2.  1.4 3.1 1.2 2.2 2.5 2.7 1.3
#  1.8 1.9 1.6 1.7 1.1]
#
# valores unicos num_of_reviews:  [  16    8   38    5   18    1   85  416    3   28   13   15   46   33
#   186  118    2  246   44   36    7   77   65  176   26    4   34  278
#    88   73   25   48    6   37   17   24  168   76   45   14   27   47
#    57  178  158   78  107   23   43   58  236  174  195   74  108  106
#    55  208   35  128  105   66   86   64   84   68  126   54   56   63
#   125  215  247  308  276  138  135  113  218  212  197   87   12  177
#   147  117   98  674  258   75  298  167   53  307   95   67  275   31
#   165  155  133   93   96  148   94  198  145  156  486  116  568  738
#   937  194  188  623  146  313  277  365   97   32  114   72  175  127
#   324  318  367  633  315  268  213  265   52  144  104  235  124  328
#   446  245  225  464  755  151  217  468  136  398  166  358  157  214
#   565  223  224  327  285  428  115  558  918  338  207  164  284   11
#   388  273  346  228  238  234  414  237  458  137  498  187  274  233
#  1248  248  796  153  295  103  143  613  765  263  196  173  266  227
#   193  134  286  438  368  528  179  306  356  297  329  684  503  251
#   518  288  154  184  395  405  426  378  264  408  102  317  256  608
#   206  111  376  845  607  211  216  448  336  366  183  387  344  204
#   434   62  635  353  377  112   83  325  394  508  172   92  412  406
#   267  354  316   91  404  226  163  666  326  445  243  507  716  205
#   323   22  709  496  364  436  287  538  293  123 1072  244   81  514
#   478  413   20  219  638  185   82  757  695  304  348  488  254  337
#  1194  444  334  132  424  357  294  130  335  271  513  482  363  203
#   181  431  332  347  537 1078  253  497  303  257  169  791  474   42
#   122 1015  418  553  546 1288  936 1483  352  305  457  525  718  628
#   793  433  798  453  554  152  758  576  938  688  603  564  345  192
#   854  222  142  296  232  668  456  848  355  885  523  778 1438  698
#   242 1055  617  644  255  838  504  658  272  396  732  656  427  717
#   548  681  645  312  588  200  407  423  442  162  292  505   29  310
#   397  527  455  373  578  788  411  437  314 1048  476  744   30  708
#   956  584 1568  536  664  728  393  466  964  383  252  454  415  447
#   737   51  161  888  361  566  495  375  590  417  493  775  322   99
#  1118  598   71  516  372  386  119  803  392  694  221  494  492 1066
#   331  618  475  465  506  385 1787  818 1125 1848  736  202  333  726
#  1818  477  129 1058  374  579  403  648  343 1084  555  678  487  452
#   676   90  533  432  311  341  435  524  191  908 1218  551  621  262
#   767  794  712  362  351  141   41  575  768  535  182  614  250  915
#   721  282  534  425  557  384  370  577  753]
#
# valores unicos price:  [None '$' '$$$' '$$' '$$$$']

# %% [markdown]
# ## Visualización general
#
# heatmap de correlación (Mapa de correlaciones)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))
sns.heatmap(df.fillna('NAN').corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f", vmin=-1, vmax=1)
plt.title("Matriz de correlación")
plt.show()

# %% [markdown]
# No se puede observar alguna relacion entre las columnas

# %% [markdown]
# ## Valores faltantes (Missing values)

# %%
# Verificamos si existen valores nulos

df.isnull().sum()
# Out:
# name                     1
# address               6227
# gmap_id                  0
# description         188231
# latitude                 0
# longitude                0
# category              1414
# avg_rating               0
# num_of_reviews           0
# price               187679
# hours                56846
# MISC                 51209
# state                53512
# relative_results     22477
# url                      0
# dtype: int64

# %%
#porcentaje de nulos

df.isnull().mean() * 100
# Out:
# name                 0.0005
# address              3.1135
# gmap_id              0.0000
# description         94.1155
# latitude             0.0000
# longitude            0.0000
# category             0.7070
# avg_rating           0.0000
# num_of_reviews       0.0000
# price               93.8395
# hours               28.4230
# MISC                25.6045
# state               26.7560
# relative_results    11.2385
# url                  0.0000
# dtype: float64

# %%
# !pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.5.2)
# Requirement already satisfied: numpy in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from missingno) (1.24.1)
# Requirement already satisfied: matplotlib in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from missingno) (3.6.3)
# Requirement already satisfied: scipy in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from missingno) (1.10.0)
# Requirement already satisfied: seaborn in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from missingno) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from seaborn->missingno) (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=0.25->seaborn->missingno) (2022.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: C:\Users\jhnnc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import missingno as msno
import pandas as pd

# Ver el gráfico de valores faltantes por columna
msno.bar(df, figsize=(12,8))

# Ver el mapa de calor de correlaciones entre valores nulos
msno.heatmap(df, figsize=(12,8))
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Duplicados

# %%
df.iloc[:, [0,1,2,3,4,5,7,8,9,12]].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Distribución y valores atípicos (outliers)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

columnas = ['latitude', 'longitude', 'avg_rating', 'num_of_reviews']

# Convertimos el DataFrame a formato largo (long-form)
df_long = df[columnas].melt(var_name='Variable', value_name='Valor')

# Creamos una figura con 2x2 subplots
fig, axs = plt.subplots(1, 4, figsize=(12, 5))  # 2 filas, 2 columnas
axs = axs.flatten()  # aplanamos para acceder más fácil

# Para cada variable, hacemos un boxplot en un subplot
for i, variable in enumerate(columnas):

    sns.boxplot(y=df[variable], ax=axs[i], )
    axs[i].set_title(f'Boxplot de {variable}')

# Ajustamos espacios
plt.tight_layout()
plt.show()
