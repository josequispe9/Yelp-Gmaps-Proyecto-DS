# %%
import pandas as pd

# Lee solo las primeras 20,000 filas del archivo JSON por cuestiones de rendimiento
df = pd.read_json('D:\\HENRY REPO\\Proyecto Final\\GOOGLE MAPS\\Metadata Sitios\\metadata-sitios-20250113T193130Z-002\\metadata-sitios\\10.json', lines=True, nrows=200000)

df.head()
# Out:
#                name                                            address  \
# 0   Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1  Clean Air Vapors  Clean Air Vapors, 401 W Main St, Riverton, WY ...
# 2          Boot Bar        Boot Bar, 702 E Main St, Riverton, WY 82501
# 3        Boysen Dam                     Boysen Dam, Shoshoni, WY 82649
# 4        Cafe Dacha  Cafe Dacha, 675 Central Ave Suite 1, Highland ...
#
#                                  gmap_id  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8
# 1  0x8758dd1117f560df:0xe691711d0c88da68
# 2  0x8758dd1d120d3c0d:0xe49a6c2994c781c0
# 3  0x8758af9fcdabbee7:0xefa71efcf509afe8
# 4  0x880fc1dd4696911b:0x1952736e51ae8b7c
#
#                                          description   latitude   longitude  \
# 0                                               None  32.388300  -83.357100
# 1                                               None  43.024439 -108.395705
# 2  Retail chain with a variety of Western & work-...  43.024925 -108.381859
# 3                                               None  43.416677 -108.177605
# 4                                               None  42.184970  -87.802011
#
#                                             category  avg_rating  \
# 0                                         [Pharmacy]         4.9
# 1                                            [Store]         4.6
# 2                                              [Bar]         4.3
# 3                               [Tourist attraction]         4.8
# 4  [Restaurant, Bar, Eastern European restaurant,...         4.8
#
#    num_of_reviews price                                              hours  \
# 0              16  None  [[Friday, 8AM–6PM], [Saturday, 8AM–12PM], [Sun...
# 1              68  None  [[Saturday, 9AM–7PM], [Sunday, Closed], [Monda...
# 2              98     $  [[Saturday, 10AM–2AM], [Sunday, 12–10PM], [Mon...
# 3              18  None                                               None
# 4              78  None  [[Saturday, 4–9PM], [Sunday, 2–8PM], [Monday, ...
#
#                                                 MISC               state  \
# 0  {'Service options': ['In-store shopping', 'Sam...   Open ⋅ Closes 6PM
# 1  {'Service options': ['In-store shopping', 'Del...   Open ⋅ Closes 7PM
# 2  {'Service options': ['Outdoor seating', 'Takeo...   Open ⋅ Closes 2AM
# 3                   {'Amenities': ['Good for kids']}            Open now
# 4  {'Service options': ['Curbside pickup', 'No-co...  Closed ⋅ Opens 4PM
#
#                                     relative_results  \
# 0  [0x88f16e41929435cf:0x5b2532a2885e9ef6, 0x88f1...
# 1            [0x8758dd1cf86fffe7:0x6bb1a35d921b6caf]
# 2  [0x8758dd1b65464237:0x76cc809276a4a18c, 0x8758...
# 3                                               None
# 4  [0x880fc105d4151ba7:0xf62bb081e163d435, 0x880f...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...

# %%
# Tamaño de Dataset

df.shape
# Out:
# (200000, 15)

# %%
# Observacion de los tipos de datos del dataset y mas informacion

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name              199999 non-null  object
#  1   address           196269 non-null  object
#  2   gmap_id           200000 non-null  object
#  3   description       22882 non-null   object
#  4   latitude          200000 non-null  float64
#  5   longitude         200000 non-null  float64
#  6   category          199151 non-null  object
#  7   avg_rating        200000 non-null  float64
#  8   num_of_reviews    200000 non-null  int64
#  9   price             25602 non-null   object
#  10  hours             155408 non-null  object
#  11  MISC              163962 non-null  object
#  12  state             158658 non-null  object
#  13  relative_results  185462 non-null  object
#  14  url               200000 non-null  object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 22.9+ MB

# %%
df.dtypes


# las columnas estan bien representadas en el formato de contenido
# Out:
# name                 object
# address              object
# gmap_id              object
# description          object
# latitude            float64
# longitude           float64
# category             object
# avg_rating          float64
# num_of_reviews        int64
# price                object
# hours                object
# MISC                 object
# state                object
# relative_results     object
# url                  object
# dtype: object

# %%
# Obsevamos las columnas del dataset

df.columns
# Out:
# Index(['name', 'address', 'gmap_id', 'description', 'latitude', 'longitude',
#        'category', 'avg_rating', 'num_of_reviews', 'price', 'hours', 'MISC',
#        'state', 'relative_results', 'url'],
#       dtype='object')

# %%
# OBERVAMOS VALORES UNICOS

print('\nvalores unicos avg_rating: ', df.avg_rating.unique())
print('\nvalores unicos num_of_reviews: ', df.num_of_reviews.unique())
print('\nvalores unicos price: ', df.price.unique())
# Out:
# valores unicos avg_rating:  [4.9 4.6 4.3 4.8 4.5 3.5 2.3 4.4 5.  4.7 3.6 3.8 4.  4.2 2.6 1.  3.7 3.2
#  4.1 3.9 3.1 2.  2.8 2.7 2.9 3.3 3.  1.8 3.4 2.4 2.2 2.5 1.9 2.1 1.6 1.5
#  1.7 1.3 1.2 1.4 1.1]
#
# valores unicos num_of_reviews:  [  16   68   98   18   78  156   27   24   48    3   65   13  107    1
#    66   38   28    6  215  288   35   26   76    5    8   67    4   34
#     7   33   10   17    2   30   47   15  138   21  134  168   45  193
#   328  413   58   84   25 1088  198   20   12  128  115   88  187  145
#   298  268  157  592  108   36   73  238  258  104  114  278  118   92
#    46  166  228  117   64  196   14  454  164  127   55   39  167  305
#    54  183  133   53  102  338  266  368  146   86 1898  285  378   94
#    22  293  144   37  458  188   77   44  124   57  158  169   71  878
#   428 1418  598  105  111  120  184   56  116  295  277   11   50   62
#   337  174   23   97  208  233  132  395  638   99  438  618  148   43
#    74  195  526   75   95  276   19  126   85   96  297  123  100  375
#    61  648   49  213   87  508  106   32  488  129   63  637   89   42
#    52  272   91  192  345   81  244  426  584  708  125  308  209  136
#   315  269  257  386  165  644  130  186  389  382  206  376    9  235
#   185  239   93   70  175   60  216  155  178  101  676  248   41  147
#   858   72  143  218  227  103  439   29   80   31   83  217  693  283
#   383  348  263  408  189  154  468   40  112  232  267  254  405  171
#    51   59  237  162  177  275  135  223  404  304  204  372  318  113
#  1608  163  173   69  300 1642  236   82  172  343  121  110  418  358
#   194  264  317  313  224  131  498  203  455  153 1925  160  492  243
#   536  253  535  294  292  122  440  325  274  207  225  234  137  400
#   255  486  788  141  388  327  391  478  565  364   90  176  477  838
#   482  515  615  159  316  532  398  623  938  150  444  978  119  678
#   558 1174  434  347  504  182  326  377  306 1420  161  212  246  370
#   109  205  226  256  362  547  140  645  524  517  583  199  197 5944
#   736  396  296  758  888  608  464  346  151  142  672  284  442  330
#   214  354  808 1184 1022  706  506  302 1058  437  367  475  336  423
#   181  516  686 1167  906  240  407  518  670  247  818  534  290  424
#   384  728  191  323  628  314  487  344  476  415  473  356  694  287
#    79  793  533  548 1357  334  738  988  324  474  825  568  152  495
#   433  335  265  813  463  412  877  446  544 1279  607 1538  597  310
#   470  242  774 1133  432  403  898  578  190 1068  355  363  725  493
#   219  635  422  549  333  307  682  202  457  958  973  553  948  245
#   465  525  419  537  374  366  887  222  768  763  282  201  286  448
#   365  249  332  747  262  456  149  577  387  727  392  373 1928  425
#   507  453  480  210  594  748  397  837  180  586  655  393 1664  522
#   321  179  778  230  528  322  658 1113  259  385  221 1108  762  542
#  1092  410  585  139  611 1048  200  231 1348  625  260 1277 1147  624
#   427  797  503  566  651  414  211  920  716  715  696  844 1037  652
#   828  650  538  593  484  273  631  741 1010  489  564  642  416  299
#   647  775 1050  353 3353 1035 2808  541  697  170  883  261  616  445
#   845  279  688 1744  394  604  626  505  220  342  241  546  675  743
#   352  698  250  351  830  443 1397 1276  529  417  402  349  554  900
#   251  431  514 1302  776  567  588  545  312  496  653 1213  280  580
#   799  667  563 1028  320  406  252 1045  513  229  502  735 1325 1118
#   357  556  673  540  677  555  466  843  331 1230  303  925  757  497
#   842 2027  613 1054  824 1018  595  575 1455 1689  796  587  340  777
#  1488  974  665  649  912  928  291  390  576  460  360  485  848  634
#   421  447  436 1481 1629  543 1127  590  668  739  435  798 1478  551
#  1008  656  341  821  965 1063 1668  309  339 1218  713  462  573  853
#  2118  654 1788  499  919  481  557  908 1465 1527 1158 1461  914  724
#   572  527  467 2125  494  401  687  703 1177  721  810 1653  359  996
#   452 1275 1126  371  657  411  579 1568  483 1623 1460  863  329  695
#   311  924 2165  930 1084 2328  937  603  718  646  955  381  785  874
#  1202  966 1036  684  961 2692 1598 1248  596 3458 1268  319  995  666
#   745  581  663 1428 1030  521 1091  641 1617 1155  982  361 1221  802
#   612 1038  705  479  281  880  472 1194 2168  753 1024 2458  680 1297
#   606  610 1681 1146 1052  271  270  866  562  954  471  947  711 1178
#   591  829  685  873 1448  744 1168  430 1571 1162 1078  602 1812  817
#   712  523 1314  350  975  639  737  510  814  560  987 1725 1175 2128
#  1676  765  907 1443  662 1958  704 2828  605  816  922  826 1128  571
#  1014  691 1208  754  574  664  674  815  918  709  968 1295 1388  856
#   710 1848 1508  692  782 2113  822 3672  369  441  847]
#
# valores unicos price:  [None '$' '$$' '$$$' '$$$$']

# %% [markdown]
# ## Visualización general
#
# heatmap de correlación (Mapa de correlaciones)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))
sns.heatmap(df.fillna('NAN').corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f", vmin=-1, vmax=1)
plt.title("Matriz de correlación")
plt.show()

# %% [markdown]
# No se puede observar alguna relacion entre las columnas

# %% [markdown]
# ## Valores faltantes (Missing values)

# %%
# Verificamos si existen valores nulos

df.isnull().sum()
# Out:
# name                     1
# address               3731
# gmap_id                  0
# description         177118
# latitude                 0
# longitude                0
# category               849
# avg_rating               0
# num_of_reviews           0
# price               174398
# hours                44592
# MISC                 36038
# state                41342
# relative_results     14538
# url                      0
# dtype: int64

# %%
#porcentaje de nulos

df.isnull().mean() * 100
# Out:
# name                 0.0005
# address              1.8655
# gmap_id              0.0000
# description         88.5590
# latitude             0.0000
# longitude            0.0000
# category             0.4245
# avg_rating           0.0000
# num_of_reviews       0.0000
# price               87.1990
# hours               22.2960
# MISC                18.0190
# state               20.6710
# relative_results     7.2690
# url                  0.0000
# dtype: float64

# %%
# !pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.5.2)
# Requirement already satisfied: numpy in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from missingno) (1.24.1)
# Requirement already satisfied: matplotlib in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from missingno) (3.6.3)
# Requirement already satisfied: scipy in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from missingno) (1.10.0)
# Requirement already satisfied: seaborn in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from missingno) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from seaborn->missingno) (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=0.25->seaborn->missingno) (2022.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\jhnnc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: C:\Users\jhnnc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import missingno as msno
import pandas as pd

# Ver el gráfico de valores faltantes por columna
msno.bar(df, figsize=(12,8))

# Ver el mapa de calor de correlaciones entre valores nulos
msno.heatmap(df, figsize=(12,8))
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Duplicados

# %%
df.iloc[:, [0,1,2,3,4,5,7,8,9,12]].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Distribución y valores atípicos (outliers)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

columnas = ['latitude', 'longitude', 'avg_rating', 'num_of_reviews']

# Convertimos el DataFrame a formato largo (long-form)
df_long = df[columnas].melt(var_name='Variable', value_name='Valor')

# Creamos una figura con 2x2 subplots
fig, axs = plt.subplots(1, 4, figsize=(12, 5))  # 2 filas, 2 columnas
axs = axs.flatten()  # aplanamos para acceder más fácil

# Para cada variable, hacemos un boxplot en un subplot
for i, variable in enumerate(columnas):

    sns.boxplot(y=df[variable], ax=axs[i], )
    axs[i].set_title(f'Boxplot de {variable}')

# Ajustamos espacios
plt.tight_layout()
plt.show()
