# %%
import pandas as pd

# Lee solo las primeras 20,000 filas del archivo JSON por cuestiones de rendimiento
df = pd.read_json('D:\\HENRY REPO\\Proyecto Final\\GOOGLE MAPS\\Metadata Sitios\\metadata-sitios-20250113T193130Z-001\\metadata-sitios\\3.json', lines=True, nrows=200000)

df.head()
# Out:
#                         name  \
# 0            Porter Pharmacy
# 1           Bumatay Jewelers
# 2                     Natura
# 3              Veterans Park
# 4  David Mac Donald Magician
#
#                                              address  \
# 0  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1  Bumatay Jewelers, 111 W Ocean Ave, Lompoc, CA ...
# 2     Natura, 10744 N Stemmons Fwy, Dallas, TX 75220
# 3  Veterans Park, 6910 New York 5&20,, Bloomfield...
# 4  David Mac Donald Magician, 64 Plaza Ave, Renss...
#
#                                  gmap_id description   latitude   longitude  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8        None  32.388300  -83.357100
# 1  0x80ec19352387c3e9:0x682efad0552e6cd4        None  34.639202 -120.458455
# 2  0x864e9d69978f66c9:0x419f97b120ab0988        None  32.873062  -96.896274
# 3  0x89d13b12eccb75e1:0x32b35c53a8cb1202        None  42.886783  -77.410820
# 4  0x89de09b96f7feb01:0x6617bbe4574de337        None  42.643592  -73.716346
#
# ...

# %%
# Tamaño de Dataset

df.shape
# Out:
# (200000, 15)

# %%
# Observacion de los tipos de datos del dataset y mas informacion

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name              199995 non-null  object
#  1   address           193187 non-null  object
#  2   gmap_id           200000 non-null  object
#  3   description       10961 non-null   object
#  4   latitude          200000 non-null  float64
#  5   longitude         200000 non-null  float64
#  6   category          198519 non-null  object
#  7   avg_rating        200000 non-null  float64
#  8   num_of_reviews    200000 non-null  int64
#  9   price             11077 non-null   object
#  10  hours             140997 non-null  object
#  11  MISC              145840 non-null  object
#  12  state             144014 non-null  object
#  13  relative_results  176122 non-null  object
#  14  url               200000 non-null  object
# dtypes: float64(3), int64(1), object(11)
# ...

# %%
df.dtypes


# las columnas estan bien representadas en el formato de contenido
# Out:
# name                 object
# address              object
# gmap_id              object
# description          object
# latitude            float64
# longitude           float64
# category             object
# avg_rating          float64
# num_of_reviews        int64
# price                object
# hours                object
# MISC                 object
# state                object
# relative_results     object
# url                  object
# dtype: object

# %%
# Obsevamos las columnas del dataset

df.columns
# Out:
# Index(['name', 'address', 'gmap_id', 'description', 'latitude', 'longitude',
#        'category', 'avg_rating', 'num_of_reviews', 'price', 'hours', 'MISC',
#        'state', 'relative_results', 'url'],
#       dtype='object')

# %%
# OBERVAMOS VALORES UNICOS

print('\nvalores unicos avg_rating: ', df.avg_rating.unique())
print('\nvalores unicos num_of_reviews: ', df.num_of_reviews.unique())
print('\nvalores unicos price: ', df.price.unique())
# Out:
# valores unicos avg_rating:  [4.9 4.6 4.5 4.4 3.5 3.4 3.8 3.  1.  4.8 3.1 4.3 5.  2.  4.  2.8 3.9 4.2
#  3.3 4.1 3.7 2.7 4.7 3.6 2.3 1.5 2.9 3.2 2.6 2.2 2.4 2.1 1.6 1.9 2.5 1.2
#  1.3 1.8 1.4 1.7 1.1]
#
# valores unicos num_of_reviews:  [  16   18    8    2    4    1   28   48   37   14   24    5    3    7
#   125   88   56  244   25   34   35   38   27   13   55   20   33   17
#     6   74   96   26  218   58   53   75  446  108   65   66   45   44
#  1325  148   93   46   15   47  166   36  178   77   54  118  205   57
#   258   78  164   84  196  138  214  778  158  217  155   73   52  268
#    97  106   68  197  124  265  228  137  113   76  348   63   98 1248
#   128  144  104   85  116  134   12  667  115  213  133  168   64  344
#   127  425   95  126  326   67  274   87  628  318  107  298  173  105
#   188  278  122   86  498  117  305  248  208  243  285  216  198   23
#    32   43  114  176  286  147  136  153  102  182  418   94  174  487
# ...

# %% [markdown]
# ## Visualización general
#
# heatmap de correlación (Mapa de correlaciones)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))
sns.heatmap(df.fillna('NAN').corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f", vmin=-1, vmax=1)
plt.title("Matriz de correlación")
plt.show()

# %% [markdown]
# No se puede observar alguna relacion entre las columnas

# %% [markdown]
# ## Valores faltantes (Missing values)

# %%
# Verificamos si existen valores nulos

df.isnull().sum()
# Out:
# name                     5
# address               6813
# gmap_id                  0
# description         189039
# latitude                 0
# longitude                0
# category              1481
# avg_rating               0
# num_of_reviews           0
# price               188923
# hours                59003
# MISC                 54160
# state                55986
# relative_results     23878
# url                      0
# dtype: int64

# %%
#porcentaje de nulos

df.isnull().mean() * 100
# Out:
# name                 0.0025
# address              3.4065
# gmap_id              0.0000
# description         94.5195
# latitude             0.0000
# longitude            0.0000
# category             0.7405
# avg_rating           0.0000
# num_of_reviews       0.0000
# price               94.4615
# hours               29.5015
# MISC                27.0800
# state               27.9930
# relative_results    11.9390
# url                  0.0000
# dtype: float64

# %%
# !pip install missingno
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: C:\Users\jhnnc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import missingno as msno
import pandas as pd

# Ver el gráfico de valores faltantes por columna
msno.bar(df, figsize=(12,8))

# Ver el mapa de calor de correlaciones entre valores nulos
msno.heatmap(df, figsize=(12,8))
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Duplicados

# %%
df.iloc[:, [0,1,2,3,4,5,7,8,9,12]].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Distribución y valores atípicos (outliers)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

columnas = ['latitude', 'longitude', 'avg_rating', 'num_of_reviews']

# Convertimos el DataFrame a formato largo (long-form)
df_long = df[columnas].melt(var_name='Variable', value_name='Valor')

# Creamos una figura con 2x2 subplots
fig, axs = plt.subplots(1, 4, figsize=(12, 5))  # 2 filas, 2 columnas
axs = axs.flatten()  # aplanamos para acceder más fácil

# Para cada variable, hacemos un boxplot en un subplot
for i, variable in enumerate(columnas):

    sns.boxplot(y=df[variable], ax=axs[i], )
    axs[i].set_title(f'Boxplot de {variable}')

# Ajustamos espacios
plt.tight_layout()
plt.show()
