# %% [markdown]
# ## Información general del dataset

# %%
# !pip install pyarrow
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 25.1
# [notice] To update, run: C:\Users\jhnnc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# Leer un archivo Parquet
df = pd.read_parquet("D:\\HENRY REPO\\Proyecto Final\\YELP\\user.parquet", engine='pyarrow')

# Mostrar las primeras filas del DataFrame
df.head()
# Out:
#                   user_id    name  review_count        yelping_since  useful  \
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker           585  2007-01-25 16:47:26    7217
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel          4333  2009-01-25 04:35:42   43091
# 2  2WnXYQFK0hXEoTxPtV2zvg   Steph           665  2008-07-25 10:41:00    2086
# 3  SZDeASXq7o05mMNLshsdIA    Gwen           224  2005-11-29 04:38:33     512
# 4  hA5lMy-EnncsH4JoR-hFGQ   Karen            79  2007-01-05 19:40:59      29
#
#    funny   cool                                              elite  \
# 0   1259   5994                                               2007
# 1  13066  27281  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 2   1010   1003                           2009,2010,2011,2012,2013
# 3    330    299                                     2009,2010,2011
# 4     15      7
#
#                                              friends  fans  ...  \
# 0  NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267  ...
# ...

# %%
# Tamaño de Dataset

df.shape
# Out:
# (2105597, 22)

# %%
# Observacion de los tipos de datos del dataset y mas informacion


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2105597 entries, 0 to 2105596
# Data columns (total 22 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   user_id             object
#  1   name                object
#  2   review_count        int64
#  3   yelping_since       object
#  4   useful              int64
#  5   funny               int64
#  6   cool                int64
#  7   elite               object
#  8   friends             object
#  9   fans                int64
#  10  average_stars       float64
#  11  compliment_hot      int64
#  12  compliment_more     int64
#  13  compliment_profile  int64
#  14  compliment_cute     int64
#  15  compliment_list     int64
#  16  compliment_note     int64
#  17  compliment_plain    int64
#  18  compliment_cool     int64
#  19  compliment_funny    int64
#  20  compliment_writer   int64
#  21  compliment_photos   int64
# dtypes: float64(1), int64(16), object(5)
# memory usage: 353.4+ MB

# %%
df.columns
# Out:
# Index(['user_id', 'name', 'review_count', 'yelping_since', 'useful', 'funny',
#        'cool', 'elite', 'friends', 'fans', 'average_stars', 'compliment_hot',
#        'compliment_more', 'compliment_profile', 'compliment_cute',
#        'compliment_list', 'compliment_note', 'compliment_plain',
#        'compliment_cool', 'compliment_funny', 'compliment_writer',
#        'compliment_photos'],
#       dtype='object')

# %%
df.iloc[0, 9
        ]
# Out:
# 267

# %%
df.dtypes

# yelping_since es un str pero deberia ser datatime
# elite es un str pero deberia ser datatime
# Out:
# user_id                object
# name                   object
# review_count            int64
# yelping_since          object
# useful                  int64
# funny                   int64
# cool                    int64
# elite                  object
# friends                object
# fans                    int64
# average_stars         float64
# compliment_hot          int64
# compliment_more         int64
# compliment_profile      int64
# compliment_cute         int64
# compliment_list         int64
# compliment_note         int64
# compliment_plain        int64
# compliment_cool         int64
# compliment_funny        int64
# compliment_writer       int64
# compliment_photos       int64
# dtype: object

# %%
# Verificamos si existen valores nulos

df.isnull().sum()
# Out:
# user_id               0
# name                  0
# review_count          0
# yelping_since         0
# useful                0
# funny                 0
# cool                  0
# elite                 0
# friends               0
# fans                  0
# average_stars         0
# compliment_hot        0
# compliment_more       0
# compliment_profile    0
# compliment_cute       0
# compliment_list       0
# compliment_note       0
# compliment_plain      0
# compliment_cool       0
# compliment_funny      0
# compliment_writer     0
# compliment_photos     0
# dtype: int64

# %%
# OBSERVAMOS VALORES UNICOS

# %%
df.elite.unique()[:10]

# existen fechas con errores de tipeo como por ejemplo el año 2020
# Out:
# array(['2007',
#        '2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,20,20,2021',
#        '2009,2010,2011,2012,2013', '2009,2010,2011', '',
#        '2006,2007,2008,2009,2010,2011,2012,2013,2014',
#        '2009,2010,2011,2012', '2007,2008,2009,2010,2011',
#        '2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,20,20,2021',
#        '2015,2016'], dtype=object)

# %%
# Observamos si existen datos duplicados

df[df.duplicated(keep=False) == True]
# Out:
#                         user_id         name  review_count  \
# 0        qVc8ODYU5SZjKXVBgXdI7w       Walker           585
# 1        j14WgRoU_-2ZE1aw1dXrJg       Daniel          4333
# 2        2WnXYQFK0hXEoTxPtV2zvg        Steph           665
# 3        SZDeASXq7o05mMNLshsdIA         Gwen           224
# 4        hA5lMy-EnncsH4JoR-hFGQ        Karen            79
# ...                         ...          ...           ...
# 2105592  4QGxxakRZeOlg_qDuxmTeQ     Jennilee            38
# 2105593  tmelBbVBGAzXBVfH2u_R6g        Gerry            19
# 2105594  tpBznnD6uJN3m_pJubj09w        Emily            26
# 2105595  Kst_srPw7GdYydMFYdCtzw  Heatheranne            25
# 2105596  mZl-mH3ZIWLRSd_FfvrXFg      Jessica            30
#
#                yelping_since  useful  funny   cool  \
# 0        2007-01-25 16:47:26    7217   1259   5994
# 1        2009-01-25 04:35:42   43091  13066  27281
# 2        2008-07-25 10:41:00    2086   1010   1003
# ...

# %% [markdown]
# ## Visualización general
#
# heatmap de correlación (Mapa de correlaciones)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))
sns.heatmap(df.fillna('NAN').corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f", vmin=-1, vmax=1)
plt.title("Matriz de correlación")
plt.show()

# %% [markdown]
# ## Valores faltantes (Missing values)

# %%
# Verificamos si existen valores nulos

df.isnull().sum()
# Out:
# user_id               0
# name                  0
# review_count          0
# yelping_since         0
# useful                0
# funny                 0
# cool                  0
# elite                 0
# friends               0
# fans                  0
# average_stars         0
# compliment_hot        0
# compliment_more       0
# compliment_profile    0
# compliment_cute       0
# compliment_list       0
# compliment_note       0
# compliment_plain      0
# compliment_cool       0
# compliment_funny      0
# compliment_writer     0
# compliment_photos     0
# dtype: int64

# %% [markdown]
# ## Duplicados

# %%
df.duplicated().sum()
# Out:
# 117700

# %% [markdown]
# ## Distribución y valores atípicos (outliers)

# %%
df_c=df.drop_duplicates()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Supongamos que tienes estas 4 columnas numéricas
df.friends.value_counts()
columnas = ['review_count', 'useful', 'funny', 'cool', 'average_stars', 'compliment_hot', 'compliment_more', 'compliment_profile', 'compliment_cute', 'compliment_list', 'compliment_note', 'compliment_plain', 'compliment_cool', 'compliment_funny', 'compliment_writer', 'compliment_photos']

# Convertimos el DataFrame a formato largo (long-form)
df_long = df_c[columnas].melt(var_name='Variable', value_name='Valor')

# Creamos una figura con 2x2 subplots
fig, axs = plt.subplots(4, 4, figsize=(18, 18))  # 2 filas, 2 columnas
axs = axs.flatten()  # aplanamos para acceder más fácil

# Para cada variable, hacemos un boxplot en un subplot
for i, variable in enumerate(columnas):

    sns.boxplot(y=df_c[variable], ax=axs[i], )
    axs[i].set_title(f'Boxplot de {variable}')

# Ajustamos espacios
plt.tight_layout()
plt.show()
